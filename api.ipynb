# %%
import requests
import csv

api_key = 'e2fc77a1070b70f63b5dbf6b046e7d50'
base_url = 'https://api.themoviedb.org/3/movie/popular'
total_pages = 1  # Toplam sayfa sayısı (örneğin, 10 sayfa)
api_key2 = 'eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiJlMmZjNzdhMTA3MGI3MGY2M2I1ZGJmNmIwNDZlN2Q1MCIsInN1YiI6IjY1MGNhNTlkNGRhM2Q0MDBlYWUyN2ZhNyIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.xnva4mZwypwwg6qVmc01aLgkM88fvbPMF8apxAwedkk'


# Tüm filmleri saklamak için boş bir liste oluşturun
all_movies = []

# TMDb API'den verileri çekin
for page in range(1, total_pages + 1):
    params = {
        'api_key': api_key,
        'page': page,
    }
    response = requests.get(base_url, params=params)
    data = response.json()
    all_movies.extend(data['results'])

# Verileri CSV dosyasına yazın
csv_file = 'movies.csv'

with open(csv_file, mode='w', newline='', encoding='utf-8') as file:
    writer = csv.writer(file)
    
    # İlk satırı başlık olarak yazın
    writer.writerow(['id','Title', 'Release Date', 'Popularity', 'Vote Average', 'Vote Count','Keywords'])

    # Her film için verileri yazın
    for movie in all_movies:
        id=movie["id"]
        title = movie['title']
        release_date = movie['release_date']
        popularity = movie['popularity']
        vote_average = movie['vote_average']
        vote_count = movie['vote_count']
        url2 = f'https://api.themoviedb.org/3/movie/{0}/keywords'.format(int(movie['id']))
        headers = {
        'Authorization': f'Bearer {api_key2}',
        'accept': 'application/json',
        }
                   
        response = requests.get(url2, headers=headers)

        data = response.text
        
    

        # Verileri CSV dosyasına yazın
        writer.writerow([id,title, release_date, popularity, vote_average, vote_count,data])

print(f"{len(all_movies)} film verisi CSV dosyasına kaydedildi: {csv_file}")
# Out:
# 20 film verisi CSV dosyasına kaydedildi: movies.csv

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\ayaza\Desktop\PYTHON İLERİ SEVİYE\Python Full Güncelleme\Web Scraping\api.ipynb Cell 2 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/ayaza/Desktop/PYTHON%20%C4%B0LER%C4%B0%20SEV%C4%B0YE/Python%20Full%20G%C3%BCncelleme/Web%20Scraping/api.ipynb#W3sZmlsZQ%3D%3D?line=0'>1</a> type(movie['id'][0])
#
# TypeError: 'int' object is not subscriptable

# %%
api_key2 = 'eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiJlMmZjNzdhMTA3MGI3MGY2M2I1ZGJmNmIwNDZlN2Q1MCIsInN1YiI6IjY1MGNhNTlkNGRhM2Q0MDBlYWUyN2ZhNyIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.xnva4mZwypwwg6qVmc01aLgkM88fvbPMF8apxAwedkk'
url2 = 'https://api.themoviedb.org/3/movie/1008042/keywords'
headers = {
    'Authorization': f'Bearer {api_key2}',
    'accept': 'application/json',
}
                   
response = requests.get(url2, headers=headers)

data = response.text

print(data)
# Out:
# {"id":1008042,"keywords":[{"id":236,"name":"suicide"},{"id":2754,"name":"trauma"},{"id":5248,"name":"female friendship"},{"id":6782,"name":"addiction"},{"id":9712,"name":"possession"},{"id":9872,"name":"grief"},{"id":11322,"name":"female protagonist"},{"id":157213,"name":"death of mother"},{"id":159315,"name":"mental health"},{"id":169075,"name":"dead parent"},{"id":178444,"name":"peer pressure"},{"id":214418,"name":"disembodied hand"},{"id":226344,"name":"generation z"},{"id":233130,"name":"self-harm"},{"id":256183,"name":"supernatural horror"},{"id":269775,"name":"adelaide australia"},{"id":283085,"name":"body horror"},{"id":296359,"name":"graphic violence"},{"id":296608,"name":"teenager"}]}

# %%
print(movies)
# Out:
# [{'adult': False, 'backdrop_path': '/iIvQnZyzgx9TkbrOgcXx0p7aLiq.jpg', 'genre_ids': [27, 53], 'id': 1008042, 'original_language': 'en', 'original_title': 'Talk to Me', 'overview': 'When a group of friends discover how to conjure spirits using an embalmed hand, they become hooked on the new thrill, until one of them goes too far and unleashes terrifying supernatural forces.', 'popularity': 2292.177, 'poster_path': '/kdPMUMJzyYAc4roD52qavX0nLIC.jpg', 'release_date': '2023-07-26', 'title': 'Talk to Me', 'video': False, 'vote_average': 7.3, 'vote_count': 686}, {'adult': False, 'backdrop_path': '/4XM8DUTQb3lhLemJC51Jx4a2EuA.jpg', 'genre_ids': [28, 80, 53], 'id': 385687, 'original_language': 'en', 'original_title': 'Fast X', 'overview': "Over many missions and against impossible odds, Dom Toretto and his family have outsmarted, out-nerved and outdriven every foe in their path. Now, they confront the most lethal opponent they've ever faced: A terrifying threat emerging from the shadows of t
# ...
